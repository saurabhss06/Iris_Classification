# %% [markdown]
# <a href="https://colab.research.google.com/github/saurabhss06/Iris_Classification/blob/main/Iris.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **DATA SCIENCE TASK** **1**

# %% [markdown]
# **IRIS FLOWER CLASSIFICATION**

# %% [markdown]
# Importing Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# %matplotlib inline

# %% [markdown]
# Loading Dataset

# %%
columns =['Sepal Length','Sepal width','Petal Length','Petal Width','Class_labels']

ab=pd.read_csv('iris.data',names=columns)
ab.head()
# Out:
#    Sepal Length  Sepal width  Petal Length  Petal Width Class_labels
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# Visualization

# %%
ab.describe()

sns.pairplot(ab,hue='Class_labels')

# %%
da=ab.values

X=da[:,0:4]
Y=da[:,4]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)

# %% [markdown]
# Support vector algo

# %%
from sklearn.svm import SVC
model_svc= SVC()
model_svc.fit (X_train, y_train)
SVC ()
# Out:
# SVC()

# %%
prediction1 = model_svc.predict (X_test)

from sklearn.metrics import accuracy_score
print (accuracy_score(y_test, prediction1))
# Out:
# 1.0

# %%
prediction1= model_svc.predict (X_test)

from sklearn.metrics import accuracy_score
print (accuracy_score(y_test, prediction1)*100)
print("----------------------------------")
print("Expected Result || Actual Result")
print("----------------------------------")
for i in range(len(prediction1)):
  
  print(y_test[i],"||", prediction1[i])
# Out:
# 100.0
# ----------------------------------
# Expected Result || Actual Result
# ----------------------------------
# Iris-versicolor || Iris-versicolor
# Iris-setosa || Iris-setosa
# Iris-setosa || Iris-setosa
# Iris-virginica || Iris-virginica
# Iris-versicolor || Iris-versicolor
# Iris-setosa || Iris-setosa
# Iris-setosa || Iris-setosa
# Iris-versicolor || Iris-versicolor
# Iris-setosa || Iris-setosa
# Iris-virginica || Iris-virginica
# Iris-setosa || Iris-setosa
# Iris-setosa || Iris-setosa
# Iris-virginica || Iris-virginica
# Iris-virginica || Iris-virginica
# Iris-setosa || Iris-setosa
# Iris-virginica || Iris-virginica
# Iris-virginica || Iris-virginica
# Iris-versicolor || Iris-versicolor
# Iris-versicolor || Iris-versicolor
# Iris-setosa || Iris-setosa
# Iris-versicolor || Iris-versicolor
# Iris-virginica || Iris-virginica
# Iris-versicolor || Iris-versicolor
# Iris-versicolor || Iris-versicolor
# Iris-virginica || Iris-virginica
# Iris-virginica || Iris-virginica
# ...

# %% [markdown]
# Regression

# %%
from sklearn.linear_model import LogisticRegression
model_LR=LogisticRegression()
model_LR.fit (X_train,y_train)
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
prediction2 = model_LR.predict(X_test)

from sklearn.metrics import accuracy_score
print (accuracy_score(y_test, prediction2) *100)
print("----------------------------------")
print("Expected Result || Actual Result")
print("----------------------------------")
for i in range(len(prediction1)):
  
  print(y_test[i],"||", prediction1[i])
# Out:
# 96.66666666666667
# ----------------------------------
# Expected Result || Actual Result
# ----------------------------------
# Iris-versicolor || Iris-versicolor
# Iris-setosa || Iris-setosa
# Iris-setosa || Iris-setosa
# Iris-virginica || Iris-virginica
# Iris-versicolor || Iris-versicolor
# Iris-setosa || Iris-setosa
# Iris-setosa || Iris-setosa
# Iris-versicolor || Iris-versicolor
# Iris-setosa || Iris-setosa
# Iris-virginica || Iris-virginica
# Iris-setosa || Iris-setosa
# Iris-setosa || Iris-setosa
# Iris-virginica || Iris-virginica
# Iris-virginica || Iris-virginica
# Iris-setosa || Iris-setosa
# Iris-virginica || Iris-virginica
# Iris-virginica || Iris-virginica
# Iris-versicolor || Iris-versicolor
# Iris-versicolor || Iris-versicolor
# Iris-setosa || Iris-setosa
# Iris-versicolor || Iris-versicolor
# Iris-virginica || Iris-virginica
# Iris-versicolor || Iris-versicolor
# Iris-versicolor || Iris-versicolor
# Iris-virginica || Iris-virginica
# ...
